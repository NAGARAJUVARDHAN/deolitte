# %%
dbutils.help()

# %%
dbutils.fs.help()

# %%
dbutils.fs.help('rm')

# %%
"""
databricks-datasets is a special, read-only directory within the Databricks File System (DBFS) that contains a curated collection of public datasets. These datasets are provided by Databricks and are available in every Databricks workspace by default.
"""
dbutils.fs.ls('databricks-datasets')

# %%
for folder in dbutils.fs.ls('databricks-datasets'):
    print(folder.path)

# %%
for folder in dbutils.fs.ls('databricks-datasets'):
    print(folder.size)

# %%
# True : recursive flag
dbutils.fs.rm('/Volumes/workspace/default/kirti_volume/sample.txt', True)

# %%
dbutils.notebook.help()

# %% [markdown]
# Create one another notebook and then we will try to execute that notebook from the cell below

# %%
dbutils.notebook.run("./103. Child Notebook-a", 300)

# %% [markdown]
# Create one more child notebook and this time we are going to pass the values to child notebook when calling it for execution

# %%
## ERROR: this is not supported in community edition

dbutils.notebook.run("./104. Child Notebook-b", 5, {"num1":"10", "num2": "20"})

# %%
# %run "./104. Child Notebook-b"

# %%
# %run "./104. Child Notebook-b" $num1=100 $num2=200

# %%
# %run "./105. Child Notebook-c" $country='US'
