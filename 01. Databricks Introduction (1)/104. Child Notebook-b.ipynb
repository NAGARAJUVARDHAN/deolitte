# %%
dbutils.widgets.help()

# %%
print('This is printed from child notebook')

# %%
dbutils.widgets.text("num1", "0", "First Value")
dbutils.widgets.text("num2", "0", "Second Value")

# %%
a = dbutils.widgets.get('num1')
b = dbutils.widgets.get("num2")

print("Addition of {} and {} is {}".format(int(a), int(b), int(a)+int(b)))
# print(f"Addition of {a} and {b} is {int(a)+int(b)}")     # just another way
