# %% [markdown]
# ### Basics of Databricks Notebooks
#
# 1. Introduction to Left Menu
# 2. Introduction to Top Menu
# 3. Adding and removing cells
# 4. Moving cells up and down
# 5. Giving heading to the cell

# %%
a = 10
b = 20
print(a,b)

# %%
print('A is:', a)
print('B is:', b)
print('Addition of A and B is:', a+b)

# %%
num = input('Enter a number')
print(num)

# %%
# %sql

CREATE TABLE If NOT EXISTS employee(empid INT, ename VARCHAR(20));

# %%
# %sql

INSERT INTO employee(empid, ename) VALUES(101, 'John');
INSERT INTO employee(ename, empid) VALUES('Bob', 102);   -- have a look at order of values

# %%
# %sql

SELECT * FROM employee;

# %% [markdown]
# # Markdown Cell

# %% [markdown]
# #Heading-1
# ##Heading-2
# ###Heading-3
#
# This is a plain text
#
# - Alpha
# - Beta
# - Gamma
#
# 1. One
# 2. Two
# 3. Three
#
# **This is bold text**
#
# _This is italic text_

# %%
# %fs

ls "/databricks-datasets"

# %%
# %fs

ls databricks-datasets/credit-card-fraud

# %%
# %fs

ls databricks-datasets/credit-card-fraud/data

# %%
# %lsmagic

# %%
# %sql
show tables;

# %%
# %sql
CREATE TABLE demo_tbl(id INT, name STRING, city STRING);

# %%
# %sql
INSERT INTO demo_tbl VALUES(101, 'Raj', 'Blr'),
                          (102, 'Akshay', 'Hyd'),
                          (103, 'Reena', 'Mumbai')

# %%
# %sql
SELECT * FROM demo_tbl

# %%
# %sql
INSERT INTO demo_tbl VALUES(104, 'Rahul', 'Blr')

# %% [markdown]
# ======================================= END =============================================
