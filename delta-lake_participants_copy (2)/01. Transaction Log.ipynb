-- %% [markdown]
-- ## Understanding Delta Lake Transaction Log
-- Understand the cloud storage directory structure behind delta lake tables

-- %% [markdown]
-- #### 0. Create a new schema under the demo catalog for this section of the course (delta_lake)

-- %%
show catalogs

-- %%
use catalog p101;

-- %%
create schema if not exists p101.p101schema
  managed location '/Volumes/p101/p101schema/sample/subfolder/data_lake';

-- %% [markdown]
-- #### 1. Create a Delta Lake Table

-- %%
drop table if exists p101.p101schema.companies;
create table p101.p101schema.companies(
  company_name string,
  founded_date date,
  country string
);

-- %%
desc extended p101.p101schema.companies;

-- %% [markdown]
-- #### 2. Insert some data

-- %%
insert into p101.p101schema.companies values('Apple','1976-04-01','USA');

-- %%
insert into p101.p101schema.companies values('Microsoft','1975-04-04','USA');
insert into p101.p101schema.companies values('Google','1998-08-14','USA');
insert into p101.p101schema.companies values('Amazon','1994-05-15','USA');
insert into p101.p101schema.companies values('SpaceX','2002-06-03','USA');

-- %%
select * from p101.p101schema.companies;

-- %% [markdown]
-- #### 3. Insert some more data
