-- %% [markdown]
-- ## Create or Replace & CTAS
-- 1. Difference between Create or Replace and Drop and Create Table statements
-- 2. CTAS statement

-- %% [markdown]
-- ### 1. Difference between Create or Replace and Drop and Create Table statements

-- %% [markdown]
-- #### Behaviour of the DROP and CREATE statements

-- %%
DROP TABLE IF EXISTS p101.p101schema.companies;

CREATE TABLE p101.p101schema.companies
  (company_id BIGINT NOT NULL GENERATED ALWAYS AS IDENTITY (START WITH 1 INCREMENT BY 1),
   company_name STRING,
   founded_date DATE,
   country      STRING);

INSERT p101.p01schema.companies 
(company_name, founded_date, country)
VALUES ("Apple", "1976-04-01", "USA"),
       ("Microsoft", "1975-04-04", "USA"),
       ("Google", "1998-09-04", "USA"),
       ("Amazon", "1994-07-05", "USA"),
       ("Tencent", "1998-11-11", "China");

-- %%
DROP TABLE IF EXISTS p101.p101schema.companies;

-- %%
DESC HISTORY sample_catalog.demo_db.companies;

-- %% [markdown]
-- #### Behaviour of the CREATE OR REPLACE statement

-- %%
DROP TABLE IF EXISTS p101.p101schema.companies;

-- %%
CREATE OR REPLACE TABLE p101.p101schema.companies
  (company_id BIGINT NOT NULL GENERATED ALWAYS AS IDENTITY (START WITH 1 INCREMENT BY 1),
   company_name STRING,
   founded_date DATE,
   country      STRING);

INSERT INTO p101.p101schema.companies 
(company_name, founded_date, country)
VALUES ("Apple", "1976-04-01", "USA"),
       ("Microsoft", "1975-04-04", "USA"),
       ("Google", "1998-09-04", "USA"),
       ("Amazon", "1994-07-05", "USA"),
       ("Tencent", "1998-11-11", "China");

-- %%
DESC HISTORY p101.p101schema.companies;

-- %% [markdown]
-- ### 2. CTAS statement

-- %%
DROP TABLE IF EXISTS p101.p101schema.companies_china;
create table p101.p101schema.comapnies_china2 
as select * from p101.p101schema.companies where country = 'China';

-- %%
select * from p101.p101schema.comapnies_china2;

-- %%
create table p101.p101schema.companies_china1
as select cast(company_id as int) as company_id, company_name, founded_date, country from p101.p101schema.companies where country = 'China';

-- %%
select * from p101.p101schema.companies_china1;

-- %%
alter table p101.p101schema.companies_china 
  alter column company_id set type int;

-- %%
desc extended p101.p101schema.companies_china;

-- %%
DESC HISTORY p101.p101schema.comapnies_china2;

-- %%
create or replace table order_tab
as 
select * from parquet.`/Volumes/workspace/default/myspace/Orders.csv`;

-- %%
CREATE OR REPLACE TABLE order_tab
AS 
SELECT * FROM read_files('/Volumes/workspace/default/myspace/Orders.csv', format => 'csv', header => true, inferSchema => true);

-- %%
select * from order_tab;

-- %%
create or replace table order_tab_csv
using delta
as 
select * from parquet.`/Volumes/workspace/default/myspace/Orders.csv`;

-- %%
create table if exists customers;
create table customers(
  customer_id int,
  customer_name string,
  customer_email string,
  customer_city string
);
insert overwrite table customers
select * from json.`path of the dataset`
